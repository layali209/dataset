# %% [markdown]
# ## **Plotly**

# %% [markdown]
# #### **Line chart**
#
#
# plot the average price of diamonds across different carat sizes.

# %% [markdown]
# ### **Stacked Area chart**
#
# Visualizing Total Carat Weight by Diamond Cut, stacked by clarity

# %% [markdown]
# ### **Bar Chart**
#
# Which cut quality gives the highest average diamond price?

# %% [markdown]
# ### **Scatter Plot**
#
# Create a scatter plot of carat vs. price

# %% [markdown]
# ### **Histogram Plot**
#
# Create a histogram for the price of diamonds

# %% [markdown]
# ### **Pie chart**
#
# Create a pie chart for the distribution of diamond cuts

# %% [markdown]
# ### **Donut chart**
#
# Create a pie chart for the distribution of diamond cuts

# %% [markdown]
# ### **Box Plot**
#
# Create a box plot for the price distribution of diamonds across different cuts

# %% [markdown]
# ## **Seaborn / Matplotlib**

# %% [markdown]
# #### **Line chart**
#
#
# plot the average price of diamonds across different carat sizes.

# %% [markdown]
# ### **Stacked Area chart**
#
# Visualizing Total Carat Weight by Diamond Cut, stacked by clarity

# %% [markdown]
# ### **Bar Chart**
#
# Which cut quality gives the highest average diamond price?

# %% [markdown]
# ### **Scatter Plot**
#
# Create a scatter plot of carat vs. price

# %% [markdown]
# ### **Scatter Plot**
#
# Create a scatter plot of carat vs. price

# %% [markdown]
# ### **Histogram Plot**
#
# Create a histogram for the price of diamonds

# %% [markdown]
# ### **Pie chart**
#
# Create a pie chart for the distribution of diamond cuts

# %% [markdown]
# ### **Donut chart**
#
# Create a pie chart for the distribution of diamond cuts

# %% [markdown]
# ### **Box Plot**
#
# Create a box plot for the price distribution of diamonds across different cuts
